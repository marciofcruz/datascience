# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       500.0  60.0     42.50   Apartamento
# 1         0.0   0.0     70.00          Casa
# 2       390.0  20.0     53.33   Apartamento
# 3       230.0   0.0     16.67   Apartamento
# 4       301.0  17.0     26.00   Apartamento

# %% [markdown]
# ## Seleção de todos os bairros

# %%
agrupamento_todos_bairros = dados.groupby('Bairro')
pd_todos_bairros = pd.DataFrame(agrupamento_todos_bairros['Valor'].mean())
pd_todos_bairros.columns = ['Valor Médio']
# pd_todos_bairros.index.name = 'Indice'
pd_todos_bairros.sort_values(by = 'Valor Médio', ascending = False, inplace = True)
pd_todos_bairros.head(20)
# Out:
#                           Valor Médio
# Bairro
# Joá                      16773.478261
# Arpoador                 12923.916667
# Cidade Jardim            12000.000000
# Paquetá                  10550.000000
# Ipanema                   9352.001134
# Itanhangá                 9341.269841
# Botafogo                  8791.828179
# São Conrado               8780.888031
# Leblon                    8746.344992
# Jardim Botânico           8722.357414
# Lagoa                     8147.075820
# Urca                      7925.958904
# Jardim Oceânico           7626.086957
# Barra da Tijuca           7069.552938
# Península                 7061.538462
# Gávea                     6563.688372
# Barra de Guaratiba        5550.000000
# Cosme Velho               5343.548387
# Freguesia (Jacarepaguá)   4966.666667
# Copacabana                4126.677005

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21826 entries, 0 to 21825
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           21826 non-null  object
#  1   Bairro         21826 non-null  object
#  2   Quartos        21826 non-null  int64
#  3   Vagas          21826 non-null  int64
#  4   Suites         21826 non-null  int64
#  5   Area           21826 non-null  int64
#  6   Valor          21826 non-null  float64
#  7   Condominio     21826 non-null  float64
#  8   IPTU           21826 non-null  float64
#  9   Valor m2       21826 non-null  float64
#  10  Tipo Agregado  21826 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.8+ MB

# %%
# bairros = ['Copacabana', 'Centro', 'Higienópolis', 'Tijuca', 'Barra da Tijuca', 'Leblon', 'Botafogo']
# selecao  = dados['Bairro'].isin(bairros)
# dados_bairro = dados[selecao]
# dados_bairro['Bairro'].drop_duplicates()

# %%
# bairros = ['Copacabana', 'Centro', 'Higienópolis', 'Tijuca', 'Barra da Tijuca', 'Leblon', 'Botafogo']
# selecao  = dados['Bairro'].isin(bairros)
# dados_bairro = dados[selecao]
# dados_bairro['Bairro'].drop_duplicates()

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
for bairro, data in grupo_bairro:
    print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Abolição -> 1195.3333333333333
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 875.0
# Andaraí -> 1464.7113402061855
# Anil -> 2048.8732394366198
# Arpoador -> 12923.916666666666
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.552938130986
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.8695652173913
# Bonsucesso -> 1225.9322033898304
# Botafogo -> 8791.828178694159
# Braz de Pina -> 1115.0
# Cachambi -> 1157.1742424242425
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1037.3333333333333
# Campo Grande -> 1267.71714922049
# Cascadura -> 948.7096774193549
# Catete -> 2267.0625
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.7521865889212
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.4285714285713
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.677004538578
# Cordovil -> 905.5555555555555
# ...

# %%
# grupo_bairro[['Valor', 'Condominio']].mean().round(2)

# %% [markdown]
# ## Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            15.0  1195.33   425.32   800.0   900.0  1180.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             4.0   875.00   132.29   700.0   812.5   900.0   962.5
# Andaraí             97.0  1464.71   408.11   700.0  1200.0  1400.0  1650.0
# Anil                71.0  2048.87  1523.97   300.0  1100.0  1500.0  2675.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      48.0  1769.58  2203.01   800.0  1000.0  1250.0  1700.0
# Vila da Penha      104.0  1260.58   644.66   450.0   900.0  1100.0  1302.5
# Vista Alegre        16.0  1114.38   199.60   700.0  1012.5  1200.0  1225.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa           9.0   861.11   174.60   600.0   800.0   850.0   950.0
#
#                        max
# Bairro
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínimo'})
# Out:
#                    Mínimo      max       sum
# Bairro
# Abolição            800.0   2300.0   17930.0
# Alto da Boa Vista   600.0  15000.0   23800.0
# Anchieta            700.0   1000.0    3500.0
# Andaraí             700.0   2950.0  142077.0
# Anil                300.0   7000.0  145470.0
# ...                   ...      ...       ...
# Vila Valqueire      800.0  16000.0   84940.0
# Vila da Penha       450.0   4500.0  131100.0
# Vista Alegre        700.0   1400.0   17830.0
# Zumbi              1600.0   2700.0    4300.0
# Água Santa          600.0   1200.0    7750.0
#
# [152 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color='blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_xlabel('Nome do Bairro')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
